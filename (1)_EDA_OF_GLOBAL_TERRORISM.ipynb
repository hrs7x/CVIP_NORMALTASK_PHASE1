# %% [markdown]
# # ***Project : Exploratory Data Analysis - Terrorism***
#
# ---

# %% [markdown]
# ***IMPORT NECESSARY LIBRARIES FOR PERFORMING EDA***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ***IMPORT THE DATASET***

# %%
df=pd.read_csv("/content/globalterrorismdb_0718dist.csv",encoding='ISO-8859-1')
# Out:
# <ipython-input-25-2d37caaa4d04>:1: DtypeWarning: Columns (4,31,33,62,76,79,94,96,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/content/globalterrorismdb_0718dist.csv",encoding='ISO-8859-1')

# %% [markdown]
# ***VIEW FIRST FIVE ENTRIES OF DATASET***

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %% [markdown]
# ***VIEW LAST FIVE ENTRIES OF DATASET***

# %%
df.tail()
# Out:
#             eventid  iyear  imonth  iday approxdate  extended resolution  \
# 18865  198305240006   1983       5    24        NaN         0        NaN
# 18866  198305240007   1983       5    24        NaN         0        NaN
# 18867  198305240008   1983       5    24        NaN         0        NaN
# 18868  198305240009   1983       5    24        NaN         0        NaN
# 18869  198305240010   1983       5    24        NaN         0        NaN
#
#        country     country_txt  region  ... addnotes scite1 scite2  scite3  \
# 18865       45        Colombia       3  ...      NaN    NaN    NaN     NaN
# 18866       45        Colombia       3  ...      NaN    NaN    NaN     NaN
# 18867      145       Nicaragua       2  ...      NaN    NaN    NaN     NaN
# 18868      145       Nicaragua       2  ...      NaN    NaN    NaN     NaN
# 18869      603  United Kingdom       8  ...      NaN    NaN    NaN     NaN
#
#        dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# ...

# %% [markdown]
# ***STATISTICAL DESCRIPTION OF THE DATASET***

# %%
df.describe()
# Out:
#             eventid         iyear        imonth          iday      extended  \
# count  1.887000e+04  18870.000000  18870.000000  18870.000000  18870.000000
# mean   1.978580e+11   1978.517011      6.198781     15.206465      0.019131
# std    3.406406e+08      3.409654      3.448318      8.955007      0.136989
# min    1.970000e+11   1970.000000      0.000000      0.000000      0.000000
# 25%    1.977042e+11   1977.000000      3.000000      8.000000      0.000000
# 50%    1.979101e+11   1979.000000      6.000000     15.000000      0.000000
# 75%    1.981082e+11   1981.000000      9.000000     23.000000      0.000000
# max    1.983052e+11   1986.000000     12.000000     31.000000      1.000000
#
#             country        region      latitude     longitude   specificity  \
# count  18870.000000  18870.000000  18123.000000  1.812300e+04  18870.000000
# mean     177.541176      5.416428     26.370738 -4.786345e+03      1.289401
# ...

# %% [markdown]
# **SHAPE OF THE DATASET**

# %%
df.shape
# Out:
# (18870, 135)

# %% [markdown]
# ***INFORMATION ABOUT NULL VALUES AND DATA TYPE***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18870 entries, 0 to 18869
# Columns: 135 entries, eventid to related
# dtypes: float64(57), int64(22), object(56)
# memory usage: 19.4+ MB

# %% [markdown]
# ***VIEW THE COLUMNS OF DATASET***

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %% [markdown]
# ***RENAMING COLUMNS***

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'state',
                       'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed',
                       'nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                       'weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)

# %% [markdown]
# **TAKE COLUMNS RELEVANT TO OUR ANALYSIS**

# %%
df=df[['Year','Month','Day','Country','state','Region','city','AttackType','Killed','Wounded','Group']]

# %% [markdown]
# ***NUMBER OF COLUMNS***

# %%
df.columns.nunique()
# Out:
# 11

# %% [markdown]
# ***TOTAL NUMBER OF NULL VALUES IN EACH COLUMN***

# %%
df.isnull().sum()
# Out:
# Year             0
# Month            0
# Day              0
# Country          0
# state           85
# Region           0
# city             0
# AttackType       0
# Killed        3522
# Wounded       5043
# Group            0
# dtype: int64

# %% [markdown]
# ***HANDLING THE MISSING VALUES***

# %%
df["Killed"]=df["Killed"].fillna('Unknown')
# Out:
# <ipython-input-36-97531d1fe647>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Killed"]=df["Killed"].fillna('Unknown')

# %%
df["Wounded"]=df["Wounded"].fillna("Wounded")
# Out:
# <ipython-input-37-989b70ee345c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Wounded"]=df["Wounded"].fillna("Wounded")

# %%
df.isnull().sum()
# Out:
# Year           0
# Month          0
# Day            0
# Country        0
# state         85
# Region         0
# city           0
# AttackType     0
# Killed         0
# Wounded        0
# Group          0
# dtype: int64

# %% [markdown]
# ***A SUMMARY ABOUT THE MOST NUMBER OF ATTACKS***

# %%
print("Country with the most attacks:",df['Country'].value_counts().idxmax())
print("City with the most attacks:",df['city'].value_counts().index[1])
print("Region with the most attacks:",df['Region'].value_counts().idxmax())
print("Year with the most attacks:",df['Year'].value_counts().idxmax())
print("Month with the most attacks:",df['Month'].value_counts().idxmax())
print("Group with the most attacks:",df['Group'].value_counts().index[1])
print("State with the most attacks:",df['state'].value_counts().idxmax())
# Out:
# Country with the most attacks: El Salvador
# City with the most attacks: Belfast
# Region with the most attacks: Western Europe
# Year with the most attacks: 1979
# Month with the most attacks: 5
# Group with the most attacks: Irish Republican Army (IRA)
# State with the most attacks: Northern Ireland

# %% [markdown]
# ***VISUALIZATION OF ATTACK OF YEARS***

# %%
x_year = df['Year'].unique()
y_count_years = df['Year'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (18,10))
sns.barplot(x = x_year,
           y = y_count_years)
plt.xticks(rotation = 45)
plt.xlabel('Attack Year')
plt.ylabel('Number of Attacks each year')
plt.title('Attack_of_Years')
plt.show()

# %% [markdown]
# ***VISUALIZATION OF ATTACK OF MONTHS***

# %%
x_month = df['Month'].unique()
y_count_month = df['Month'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (18,10))
sns.barplot(x = x_year,
           y = y_count_years)
plt.xticks(rotation = 45)
plt.xlabel('Attack Month')
plt.ylabel('Number of Attacks each month')
plt.title('Attack_of_Months')
plt.show()

# %% [markdown]
# ***VISUALIZATION OF ATTACK OF DAYS***

# %%
x_day = df['Day'].unique()
y_count_day = df['Day'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (18,10))
sns.barplot(x = x_year,
           y = y_count_years)
plt.xticks(rotation = 45)
plt.xlabel('Attack Day')
plt.ylabel('Number of Attacks each day')
plt.title('Attack_of_Days')
plt.show()

# %% [markdown]
# ***VISUALIZATION OF ATTACKTYPE***

# %%
x_attacktype = df['AttackType'].unique()
y_count_attacktype = df['AttackType'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (18,10))
sns.barplot(x = x_year,
           y = y_count_years)
plt.xticks(rotation = 45)
plt.xlabel('Attack Type')
plt.ylabel('Number of Attacks')
plt.title('Attack_Type')
plt.show()

# %% [markdown]
# ***VISUALIZATION OF TERRORIST ACTIVITIES BY REGION IN EACH YEAR***

# %%
pd.crosstab(df.Year, df.Region).plot(kind='area',figsize=(15,6))
plt.title('Terrorist Activities by Region in each Year')
plt.ylabel('Number of Attacks')
plt.show()

# %% [markdown]
# ***VISUALIZATION OF TERRORIST ACTIVITIES BY REGION IN EACH MONTH***

# %%
pd.crosstab(df.Month, df.Region).plot(kind='area',figsize=(15,6))
plt.title('Terrorist Activities by Region in each Month')
plt.ylabel('Number of Attacks')
plt.show()

# %% [markdown]
# ***VISUALIZATION OF TERRORIST ACTIVITIES BY REGION IN EACH DAY***

# %%
pd.crosstab(df.Day, df.Region).plot(kind='area',figsize=(15,6))
plt.title('Terrorist Activities by Region in each Day')
plt.ylabel('Number of Attacks')
plt.show()

# %% [markdown]
# ***END OF THE PROJECT***
